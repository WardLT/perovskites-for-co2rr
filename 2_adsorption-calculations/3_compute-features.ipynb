# %% [markdown]
# # Compute Features for the Data
# Use the basic feature set of [Ward et al.](https://www.nature.com/articles/npjcompumats201628)

# %%
from matminer.featurizers import composition as cf
from matminer.featurizers.base import MultipleFeaturizer
from matminer.utils.data import MagpieData
from pymatgen.core import Composition, Element
from pathlib import Path
import pandas as pd

# %% [markdown]
# Configuration

# %%
elem_feature_names = [
    "Number", "MendeleevNumber", "AtomicWeight", "MeltingT", "Column", "Row", "CovalentRadius", "Electronegativity", 
    "NsValence", "NpValence", "NdValence", "NfValence", "NValence", "NsUnfilled", "NpUnfilled", "NdUnfilled", "NfUnfilled", "NUnfilled",
    "GSvolume_pa", "GSbandgap", "GSmagmom", "SpaceGroupNumber"
]

# %% [markdown]
# ## Load the Dataset and Featurize the Formula
# Load a dataset, compute the features, save it as a new file

# %%
featurizer = MultipleFeaturizer([
      cf.Stoichiometry(),
      cf.ElementProperty.from_preset('magpie'),
      cf.ValenceOrbital(props=['frac']),
      cf.IonProperty(fast=True)
])

# %% [markdown]
# Load the adsorption dataset

# %%
data = pd.read_csv('adsorbates.csv')
print(f'Loaded a total of {len(data)} adsorption energies')
data.query('site_charge > 0', inplace=True)  # Ignore unblaanced charges
print(f'Loaded {len(data)} adsorption energies for charge-balanced materials')
data.head()
# Out:
# Loaded a total of 1825 adsorption energies
# Loaded 1599 adsorption energies for charge-balanced materials
#      comp  term        site surface_comp site_atom  site_charge   a   b  \
# 0  NdRhO3     1  mono_metal         RhO2        Rh            4  Nd  Rh
# 1  NdRhO3     1   pi_oxygen         RhO2        Rh            4  Nd  Rh
# 2  NdRhO3     0  mono_metal          NdO        Nd            2  Nd  Rh
# 3  NdRhO3     0    pi_metal          NdO        Nd            2  Nd  Rh
# 4  CaGeO3     1    pi_metal         GeO2        Ge            4  Ca  Ge
#
#    a_val  b_val  supercell  adsorption_energy  gap  o2p_center  d_center  \
# 0      2      4          2           0.689499  NaN         NaN       NaN
# 1      2      4          2           0.187609  NaN         NaN       NaN
# 2      2      4          2          -0.506608  NaN         NaN       NaN
# 3      2      4          2           0.149078  NaN         NaN       NaN
# 4      2      4          2           0.077240  NaN         NaN       NaN
#
#    A_charge  B_charge  O_charge
# 0       NaN       NaN       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4       NaN       NaN       NaN

# %% [markdown]
# Compute features for the bulk material

# %%
data['comp_obj'] = data['comp'].apply(Composition)
bulk_features = featurizer.featurize_dataframe(data, 'comp_obj')
bulk_features = bulk_features.iloc[:, len(data.columns):]  # Only get the new columns
# Out:
# MultipleFeaturizer: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1599/1599 [00:00<00:00, 4557.26it/s]

# %% [markdown]
# Rename features to have the word "bulk" in front of them

# %%
bulk_features.rename(columns=lambda x: f'bulk_{x}', inplace=True)
bulk_features.head()
# Out:
#    bulk_0-norm  bulk_2-norm  bulk_3-norm  bulk_5-norm  bulk_7-norm  \
# 0            3     0.663325     0.614463     0.600984     0.600078
# 1            3     0.663325     0.614463     0.600984     0.600078
# 2            3     0.663325     0.614463     0.600984     0.600078
# 3            3     0.663325     0.614463     0.600984     0.600078
# 4            3     0.663325     0.614463     0.600984     0.600078
#
#    bulk_10-norm  bulk_MagpieData minimum Number  \
# 0      0.600002                             8.0
# 1      0.600002                             8.0
# 2      0.600002                             8.0
# 3      0.600002                             8.0
# 4      0.600002                             8.0
#
#    bulk_MagpieData maximum Number  bulk_MagpieData range Number  \
# 0                            60.0                          52.0
# 1                            60.0                          52.0
# 2                            60.0                          52.0
# 3                            60.0                          52.0
# 4                            32.0                          24.0
#
#    bulk_MagpieData mean Number  ...  bulk_MagpieData mean SpaceGroupNumber  \
# 0                         25.8  ...                                   91.0
# 1                         25.8  ...                                   91.0
# 2                         25.8  ...                                   91.0
# 3                         25.8  ...                                   91.0
# 4                         15.2  ...                                   97.2
#
#    bulk_MagpieData avg_dev SpaceGroupNumber  \
# 0                                     94.80
# 1                                     94.80
# 2                                     94.80
# 3                                     94.80
# 4                                    102.24
#
#    bulk_MagpieData mode SpaceGroupNumber  bulk_frac s valence electrons  \
# 0                                   12.0                       0.272727
# 1                                   12.0                       0.272727
# 2                                   12.0                       0.272727
# 3                                   12.0                       0.272727
# 4                                   12.0                       0.294118
#
#    bulk_frac p valence electrons  bulk_frac d valence electrons  \
# 0                       0.363636                       0.242424
# 1                       0.363636                       0.242424
# 2                       0.363636                       0.242424
# 3                       0.363636                       0.242424
# 4                       0.411765                       0.294118
#
#    bulk_frac f valence electrons  bulk_compound possible  bulk_max ionic char  \
# 0                       0.121212                    True             0.733532
# 1                       0.121212                    True             0.733532
# 2                       0.121212                    True             0.733532
# 3                       0.121212                    True             0.733532
# 4                       0.000000                    True             0.774266
#
#    bulk_avg ionic char
# 0             0.133399
# 1             0.133399
# 2             0.133399
# 3             0.133399
# 4             0.149945
#
# [5 rows x 145 columns]

# %% [markdown]
# Compute features for the element on the surface

# %%
elem_features = pd.DataFrame()
elems = data['site_atom'].apply(Element)
magpie_data = MagpieData()
for e in elem_feature_names:
    elem_features[f'site_{e}'] = magpie_data.get_elemental_properties(elems, e)

# %%
elem_features.head()
# Out:
#    site_Number  site_MendeleevNumber  site_AtomicWeight  site_MeltingT  \
# 0         45.0                  59.0           102.9055         2237.0
# 1         45.0                  59.0           102.9055         2237.0
# 2         60.0                  19.0           144.2420         1294.0
# 3         60.0                  19.0           144.2420         1294.0
# 4         32.0                  79.0            72.6400         1211.4
#
#    site_Column  site_Row  site_CovalentRadius  site_Electronegativity  \
# 0          9.0       5.0                142.0                    2.28
# 1          9.0       5.0                142.0                    2.28
# 2          3.0       6.0                201.0                    1.14
# 3          3.0       6.0                201.0                    1.14
# 4         14.0       4.0                120.0                    2.01
#
#    site_NsValence  site_NpValence  ...  site_NValence  site_NsUnfilled  \
# 0             1.0             0.0  ...            9.0              1.0
# 1             1.0             0.0  ...            9.0              1.0
# 2             2.0             0.0  ...            6.0              0.0
# 3             2.0             0.0  ...            6.0              0.0
# 4             2.0             2.0  ...           14.0              0.0
#
#    site_NpUnfilled  site_NdUnfilled  site_NfUnfilled  site_NUnfilled  \
# 0              0.0              2.0              0.0             3.0
# 1              0.0              2.0              0.0             3.0
# 2              0.0              0.0             10.0            10.0
# 3              0.0              0.0             10.0            10.0
# 4              4.0              0.0              0.0             4.0
#
#    site_GSvolume_pa  site_GSbandgap  site_GSmagmom  site_SpaceGroupNumber
# 0            13.640           0.000            0.0                  225.0
# 1            13.640           0.000            0.0                  225.0
# 2            34.810           0.000            0.0                  194.0
# 3            34.810           0.000            0.0                  194.0
# 4            23.005           0.383            0.0                  225.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Concatentate and save

# %%
pd.concat([data.drop(columns=['comp_obj']), bulk_features, elem_features], axis=1).to_csv('../datasets/adsorption-regression.csv', index=False)

# %% [markdown]
# ## Make a classification version
# Get the most-stable surface site for each perovskite and its energy

# %%
by_comp = data.value_counts('comp').to_dict()

# %%
data['fraction_complete'] = data['comp'].apply(lambda x: by_comp[x] / 8)
data['class'] = [f't{t}-{s}' for t, s in zip(data['term'], data['site'])]

# %%
top_surface = pd.concat([data.drop(columns=['comp_obj']), bulk_features], axis=1).sort_values('adsorption_energy', ascending=True).drop_duplicates('comp', keep='first')

# %%
top_surface.to_csv('../datasets/adsorption-classification.csv', index=False)
